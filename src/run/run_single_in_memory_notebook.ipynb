# %% [markdown]
# # Single Image Filter Example
# ###### This File shows how to modify a single image from disk, with only one load at the beginning.

# %% [markdown]
# <br/><br/>
# ### Setup ------------------------------------------------------
# This is just imports, path stuff, and helper functions

# %%
# Helpers
import os
changed=False

def where():
    print("Current Directory: \n{}".format(os.getcwd()))
    
def change_directory(directory, changed):

    dir_out=os.path.join(directory, "src")
    if not directory in os.getcwd():
        os.chdir(os.path.join(os.getcwd(), dir_out))
    if not changed:
        new_path = os.path.join(os.getcwd(), "..")
        os.chdir(new_path)
    changed=True
    where()

# %%
# Go where you need to go for the imports
if not changed:
    change_directory('sunback', changed)
    changed = True
    
# Imports
from fetcher.LocalFetcher import LocalSingleFetcher
from processor.ImageProcessorCV import ImageProcessorCV
from processor.SRNSubProcessors import SRNradialFiltProcessor, SRNSingleShotProcessor

from science.parameters import Parameters
from run import Runner, SingleRunner
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib ipympl
# %matplotlib notebook
# Out:
# Current Directory:
# C:\Users\chgi7364\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src

# %%
# Go to the directory with the single image
# test_directory = r"/srv/data/shared/notebooks/cgilly/sunback/src/sunback_images/Single/"
test_directory = r"D:/sunback_images/Single/"
# test_image = r"aia.lev1_euv_12s.2013-09-29T000009Z.304.image_lev1.fits"
test_image = r"aia.lev1_euv_12s.2013-10-02T162012Z.171.image_lev1.fits"

test_path = os.path.join(test_directory, test_image)
os.chdir(test_directory)
where()
# Out:
# Current Directory:
# D:\sunback_images\Single

# %% [markdown]
# <br/><br/>
# ### Set Parameters -------------------------------------------------------------------

# %% [markdown]
# Now we can set the program data. First you instantiate a Parameters object, then set a couple of settings.

# %%
p = Parameters()

p.use_image_path(test_path)
p.batch_name("Single")
p.do_single = True
p.run_type("Process a Single Image")
p.do_one(True, True)
p.is_debug(True)
p.destroy = False

# %% [markdown]
# Sunback works by using *processors* to sequentially modify images. There are many processors available in sunback. This example only uses three, but you can string together as many as you want.

# %% [markdown]
# This is how you decide which processors you want to actually use:

# %%
# Set the Processesors
p.fetchers(LocalSingleFetcher,          rp=True)  # Get the desired file
# I copied over a curves.txt file that was trained on a larger dataset. 
p.processors([SRNSingleShotProcessor],  rp=True)  # Apply the SRN Filter
p.putters([ImageProcessorCV],           rp=True)  # Makes the PNGs from Fits
# Out:
# [putter.NullPutter.NullPutter, processor.ImageProcessorCV.ImageProcessorCV]

# %% [markdown]
# Processors that are dropped directly into the method run alone, while those nested inside a list will be appended to the current list of that type of processor. The rp parameter tells if the processor will be repeated on subsequent runs (Not super relevant to one-shots). Fetchers, processors, and putters are all child classes of Processor, with a couple of child-methods specific to each one added.

# %% [markdown]
# <br/><br/>
# ### Run the Filter --------------------------------------------------------

# %% [markdown]
# Finally, you start the code. The Runner class will apply each of the selected processors to every fits file in a directory, whereas the SingleRunner will apply each processor to a single image without saving and loading. Support for doing all the steps to a single image at a time in a directory of many images is in-prep.

# %%
# Run the Code
SingleRunner(p).start()
# Out:
#  *****************************************************************
#
# Sunback SDO Image Manipulator
# Written by C.R. Gilly
# Check out my website: http://gilly.space
#
# DEBUG MODE
#
# Run Name: Single
# Run Type: Process a Single Image
#
#  Here's the Plan:
#    Local Single Fetcher	 : 	Load the image from Disk
#    SRN Single Shot Processor	 : 	Create and Apply the Radial SRN Curves
#    CV Image Writer	 : 	Turn all the fits files into png files
#   And Stop After One Loop
#
#  *****************************************************************
#
#
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Starting Job: Single
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
#
# >>-->>  Local Single Fetcher: Load the image from Disk  <<--<<
#  v Loading Local File...
# Using t_integrated HDU
#       D:/sunback_images/Single
#       aia.lev1_euv_12s.2013-10-02T162012Z.171.image_lev1.fits
#  ^ Success!
#
# >>-->>  SRN Single Shot Processor: Create and Apply the Radial SRN Curves  <<--<<
#  v  Processing Image...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27368/1731034838.py in <module>
#       1 # Run the Code
# ----> 2 SingleRunner(p).start()
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\run\run.py in start(self)
#      19
#      20         if self.params.is_debug():
# ---> 21             self.__debug_mode()
#      22         else:
#      23             self.__run_mode()
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\run\run.py in __debug_mode(self)
#      26         """Run the program in a way that will break"""
#      27         while True:
# ---> 28             self.process()
#      29             if self.params.stop_after_one():
#      30                 break
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\run\run.py in process(self)
#      59         and putter to do the thing"""
#      60         if type(self) is SingleRunner:
# ---> 61             self.process_single()
#      62             return
#      63
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\run\run.py in process_single(self)
#     177         self.print_start_banner()
#     178         self.assemble_processors()
# --> 179         self.do_process()
#     180         self.print_end_banner()
#     181
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\run\run.py in do_process(self)
#     208             # proc.process(image=self.params.use_image_path())
#     209             print(">>-->>  {}: {}  <<--<<".format(proc.filt_name, proc.description))
# --> 210             proc.process()
#     211             print('')
#     212
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\processor\Processor.py in process(self, params)
#     381         if self.params is not None:
#     382             if self.params.do_single:
# --> 383                 self.process_image()
#     384             elif self.do_png:
#     385                 self.process_img_series()
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\processor\Processor.py in process_image(self)
#     390         """Apply the function to a single image"""
#     391         self.setup()
# --> 392         self.modify_one_image()
#     393         self.cleanup()
#     394
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\processor\Processor.py in modify_one_image(self)
#     448     def modify_one_image(self,):
#     449         """Apply the given funtion to the given fits path"""
# --> 450         self.params.modified_image = self.do_img_function()
#     451
#     452
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\processor\SRNProcessor.py in do_img_function(self)
#     176     def do_img_function(self):
#     177         """Calls the do_work function on a single fits path if indicated"""
# --> 178         return self.do_work()  # Do the work on the fits files
#     179
#     180     ###################
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\processor\SRNSubProcessors.py in do_work(self)
#      44         if verb:
#      45             print(" v ", self.progress_verb, "Image...")
# ---> 46         self.image_learn()  # Analyze the input to help make normalization curves
#      47 #         self.plot_norm_curves(save=False, show=True, extra=True)
#      48         self.image_modify()  # Actually Normalize This Image
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\processor\SRNProcessor.py in image_learn(self)
#     191             self.init_for_learn()
#     192             self.bin_radially()  # Create a cloud of intesity values for each radial bin
# --> 193             self.radial_statistics()  # Find mean and percentiles vs height
#     194             self.add_to_keyframes()  # Update the running curves
#     195             self.make_smoothed_curves()
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\processor\SRNProcessor.py in radial_statistics(self)
#     551         for ii, bin_list in enumerate(self.radBins):
#     552             self.store_bin_array(ii, bin_list)
# --> 553         self.finalize_radial_statistics()
#     554
#     555     def store_bin_array(self, ii, bin_list):
#
# ~\Dropbox\AB_Interesting_Stuff\Projects\sunback_proj\src\processor\SRNProcessor.py in finalize_radial_statistics(self)
#     577         idx = np.isfinite(self.binMax) & np.isfinite(self.binMin)
#     578         n_index = self.binAbss[idx]
# --> 579         self.frame_abss[n_index] = n_index
#     580         self.frame_maximum[n_index] = self.binMax[idx]
#     581         self.frame_minimum[n_index] = self.binMin[idx]
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed
