# %% [markdown]
# # SRN on panHelio
# ######  This is the most "black box" version of the code

# %% [markdown]
# ### Imports

# %%
import run_panhelio as rp
import os
# Out:
# /srv/data/shared/notebooks/cgilly/sunback/src
# Cannot load backend 'Qt5Agg' which requires the 'qt5' interactive framework, as 'headless' is currently running

# %% [markdown]
# ### Define the Image

# %%
test_directory = r"/srv/data/shared/notebooks/cgilly/sunback/src/sunback_images/Single/"
test_image = r"AIA20210923_172100.nc"
test_path = os.path.join(test_directory, test_image)
print(test_path)
# Out:
# /srv/data/shared/notebooks/cgilly/sunback/src/sunback_images/Single/AIA20210923_172100.nc

# %% [markdown]
# ### Run the code

# %%
# Run the code on that image
rp.run(test_path, verb=False, confirm=True)
# Out:
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Starting Job: Single
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
#
# >>-->>  Local Single CDF Fetcher: Load the image from Disk  <<--<<
#  v Loading Local File...
#    Looking in:
#      /srv/data/shared/notebooks/cgilly/sunback/src/sunback_images/Single
#      for AIA20210923_172100.nc  at  20210923_172100
#
# >>-->>  SRN Single Shot Processor: Create and Apply the Radial SRN Curves  <<--<<
#  v  Processing Image...
#    New CDF saved to
#     /srv/data/shared/notebooks/cgilly/sunback/src/sunback_images/Single/AIA20210923_172100_filtered.nc
#
#    V Plotting Confirmation of Reduction:
#       Original:
#
#       Modified:
#
#    ^ We Plotted!
#
#  ^ Success!
#
#
# >>-->>  NullPutter: Print the Name of the Image Folder  <<--<<
#  /srv/data/shared/notebooks/cgilly/sunback/src/sunback_images/Single/sunback_images/Single
#
#
#
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Program Complete in 0 minutes and 3 seconds.
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_

# %% [markdown]
# It really does seem like the plotting should work. Not sure why it doesn't, but it works here: https://sprints-hub.nextgenfed.com/user/cgilly/notebooks/shared/notebooks/cgilly/sunback/src/run/sunback_netcdf_notebook.ipynb
#
# This version of the code is using a bit of an old tuning for the filters; we are working on a method that gets much better results!
