# %% [markdown]
# # SRN on panHelio
# ### Called by importing and running a function
# ######  This is the most "black box" version of the code, BATCHED

# %% [markdown]
# ### Imports

# %%
import run_panhelio as rp
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib ipympl
# %matplotlib notebook
# Out:
# /srv/data/shared/notebooks/cgilly/sunback/src
# Cannot load backend 'Qt5Agg' which requires the 'qt5' interactive framework, as 'headless' is currently running

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ### Define the Target Directory

# %%
test_directory = r"/srv/data/shared/notebooks/cgilly/sunback/src/sunback_images/Single/"

# %% [markdown]
# ### Run the code
#  Set verb = True to display much more output
#  Set confirm = True to display plots

# %%
rp.run_batch(test_directory, confirm=False)
# Out:
# Looking in
#   /srv/data/shared/notebooks/cgilly/sunback/src/sunback_images/Single/
#     Found 3 images
# 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]

# %% [markdown]
# ### Confirmation of Save

# %%
import os
items = os.listdir(test_directory)
items.sort()
_=[print(x) for x in items if '.nc' in x]
# Out:
# AIA20210923_172100-Copy1.nc
# AIA20210923_172100-Copy1_filtered.nc
# AIA20210923_172100-Copy2.nc
# AIA20210923_172100-Copy2_filtered.nc
# AIA20210923_172100.nc
# AIA20210923_172100_filtered.nc

# %% [markdown]
# A new file has been created next to the original with "_filtered" appended to the name.

# %% [markdown]
# ### Future Work

# %% [markdown]
# This code is using a bit of an old tuning for the filters; we are also working on another method that gets much better results!
